# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanmaxibt/Data/blob/main/%E2%80%9CProyecto_Final%2BIv%C3%A1n%2BBustos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Índice**
#
# 1.   [Abstract](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=kttpkLvqEJC4)
# 2.   [Objetivo](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=OukSH3ZdF5Tm)
# 3.   [Contexto comercial](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=3DoresBRIq-Q)
# 4.   [Problema Comercial](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=8mcIefBXJN7C)
# 5.   [Exploración de datos (EDA)](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=rxWxgQ6MK4sN)
# 6.   [Base de datos seleccionada](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=s0hdZMBdJcPt)
#   *    [Descripción (Análisis detallado de cada variable)](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=KK5JPKOeJe5V)
# 7.   [Primeros pasos](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=Sohtl6R9Jp5E)
#   *   [Cargado de las librerías a utilizar para poder analizar y trabajar los datos.](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=vNu1K-GlJw9a)
#   *   [Análisis de los tipos de datos](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=1x2PByceKU2t)
#   *   [Análisis de elementos nulos por columnas](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=HTNUY-xkLZqL)
#   *   [Utilización del método .groupby() para calcular la media anual para cada contaminante:](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=BsBvZyYUL3EL)
# 8.   [Gráficos](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=qGy7l6tXMT5z)
# *   **Matplotlib**
#     *   [*Gráfico de Línea*](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=0qaY54vUMlKM)
#     *   [*Histograma*](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=YZ9R_ECmNA07)
#     *   [*Boxplot*](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=pFfAOA-AN6Zq)
# *   **Seaborn**
#     *   [*Countplot*](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=CCKlj-KWPECo)
#     *   [*Barplot*](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=2hiJuGA_UjDn)
#     *   [*Boxplot*](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=dHXIx0CMVk-f)
# 9.   [Herramientas de visualización y Preprocesamiento estadístico de los datos](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=eKCu838QMuuk)
#   *   [Filtrado de la cantidad total de emisiones domésticas (cantidades nacionales de cada contaminante por año en KG/HAB)](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=Prs2lt2iMSdd)
#   *   [Continúo trabajando con la matriz](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=dbeR-aMKOsW1)
# 10.   **Preguntas y respuestas**
#   *   [Evolución de las emisiones de CO2 en el tiempo ¿Crecieron o disminuyeron?](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=3HCPbyvCPAvk)
#   *   [¿Los NOx están en retroceso?](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=flmrhfQBP29s)
#   *   [¿En qué rangos entre los que se movió el metano en los años estudiados?](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=0QBmD3leQGKU)
#   *   [La tendencia del CO ¿es a la baja?](https://colab.research.google.com/drive/1r5tKUEWlXaZ_8uZV4vZOMmnJKVtMDztZ#scrollTo=CkO9nU7ZQVhb)
# 11.   **Métodos de regresión**
#   *   [Selección de Características: Selección Iterativa](https://colab.research.google.com/drive/1JenKcEIKvAZu8nNIWrGpwqKTolunTS55#scrollTo=xVjZee6za6CS)
#   *   [Forward Selection](https://colab.research.google.com/drive/1JenKcEIKvAZu8nNIWrGpwqKTolunTS55#scrollTo=Lzx9IvvK5ebx)
#   *   [Backward Selection](https://colab.research.google.com/drive/1JenKcEIKvAZu8nNIWrGpwqKTolunTS55#scrollTo=nmjuiMFa5woW)
#   *   [Eliminación bidireccional (stepwise)](https://colab.research.google.com/drive/1JenKcEIKvAZu8nNIWrGpwqKTolunTS55#scrollTo=c82Cagpn59nd)
# 12.   **Modelos de regresión**
#   *   [Algoritmos de regresión](https://colab.research.google.com/drive/1JenKcEIKvAZu8nNIWrGpwqKTolunTS55#scrollTo=t8qpahEBfHiE)
#   *   [Regresión Lineal](https://colab.research.google.com/drive/1JenKcEIKvAZu8nNIWrGpwqKTolunTS55#scrollTo=zLc8Oy6O6e2j)
#   *   [Regresión Múltiple](https://colab.research.google.com/drive/1JenKcEIKvAZu8nNIWrGpwqKTolunTS55#scrollTo=gzucT_PS-Fjk)
# 13. [**Data Wrangling**](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=cXxzhzPJZCn4)
#   *   [Selección de API](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=mza_dcASl5IV)
#   *   [¿Se escriben artículos relacionados a esta problemática?](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=I4E_oEeFdL)
#   *   [¿Quiénes son los escritores qué escriben sobre cambio climático?](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=97Clvka2XMKy)
#   *   [¿Cuántos escritores son?](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=Rc1YPn0MXxwA)
#   *   [¿Cuántos artículos publica la BBC en Facebook sobre Cambio Climático?](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=ZwXSAwBdYq8N)
# 14.   [**Modelos de Machine Learning**](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=bSfJZpOH__ie)
#   *   [Regresión Lineal](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=1ysKvos69o78)
#   *   [CrossValidation](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=uzm-0AWG_McW)
#   *   [RandomForestRegressor vs XGBRegressor](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=AGWmnzIpPiwM)
#   *   [RandomForestRegressor](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=X2eC4EP6QvNx)
#   *   [XGBRegressor](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=Jn4VIIcdQ0_v)
# 15. [**Conclusión**](https://colab.research.google.com/drive/1b3VCqi6IlZRMvimvdA3beyWO006vWgP0#scrollTo=DNDHT3FkVMKB)

# %% [markdown]
# # **Abstract**
#
# Elegí esta base de datos principalmente por su tamaño y temática. Mi idea fue poder trabajar con ella, ordenarla, entenderla y procesarla para a posterior poder utilizarla en Data Science.
#
# ∫	Tamaño: La misma posee 173665 filas y 17 columnas agrupando 2.952.305 datos.
#
# ∫	Temática: son mediciones de emisiones de gases de efecto invernadero y contaminantes atmosféricos procedentes de 28 países de la Unión Europea entre los años 2008 a 2018.
#
# Los gases de efecto invernadero tienen efectos de gran alcance sobre el medio ambiente y la salud. Provocan el cambio climático al atrapar el calor y también contribuyen a las enfermedades respiratorias causadas por el smog y la contaminación atmosférica. El clima extremo, las alteraciones del suministro de alimentos y el aumento de los incendios forestales son otros efectos del cambio climático provocado por los gases de efecto invernadero. Los patrones meteorológicos típicos a los que estamos acostumbrados cambiarán; algunas especies desaparecerán; otras emigrarán o crecerán.
#
# Al atrapar el calor del sol, los gases de efecto invernadero han mantenido el clima de la Tierra habitable para los seres humanos y millones de otras especies. Pero esos gases están ahora desequilibrados, y amenazan con cambiar drásticamente qué seres vivos pueden sobrevivir en este planeta, y dónde.
#
# Prácticamente todos los sectores de la economía mundial, desde la industria manufacturera a la agricultura, pasando por el transporte y la producción de energía, contribuyen con gases de efecto invernadero a la atmósfera, por lo que todos ellos deben alejarse de los combustibles fósiles si queremos evitar los peores efectos del cambio climático.

# %% [markdown]
# # **Objetivo**
#
#  Mi principal objetivo es corrobar desde el punto de vista empírico si las políticas públicas aplicadas en la Unión Europea han coincidido con los objetivos. Para llevar a cabo la siguiente tarea voy a realizar los análisis correspondientes, tomando como punto de partida los datos. Dicha base de datos fue extraída de Kaggle.

# %% [markdown]
# # **Contexto Comercial**
#
#  El régimen de comercio de derechos de emisión de la UE (RCDE UE) es un mercado de carbono basado en un sistema de cantidades máximas e intercambios de derechos de emisión para los sectores de gran consumo de energía y para el sector de la generación de electricidad.

# %% [markdown]
# # **Problema Comercial**
#
#  El mercado de carbono es la principal herramienta de la UE para abordar la reducción de las emisiones. Desde su introducción en 2005, las emisiones de la UE han disminuido un 41 %.

# %% [markdown]
# # **Exploración de datos (EDA)**
#
# El análisis exploratorio de datos (EDA) es un enfoque estadístico que se utiliza para obtener información sobre un conjunto de datos. Se utiliza para resumir los datos, identificar patrones y valores atípicos y evaluar la estructura subyacente de los datos.
# El EDA es un paso importante en cualquier proyecto de análisis de datos, ya que ayuda a identificar las variables más importantes y las relaciones entre ellas. También puede ayudar a identificar qué métodos de análisis de datos son los más adecuados para el conjunto de datos.
# El AED suele realizarse con métodos visuales, como los gráficos de dispersión y los histogramas. Sin embargo, también pueden utilizarse otros métodos, como las pruebas estadísticas.

# %% [markdown]
# **Base de Datos Seleccionada:**
# # "Emisiones de gases de efecto invernadero y contaminantes atmosféricos procedentes de 28 países de la Unión Europea entre los años 2008 a 2018"

# %% [markdown]
# El conjunto de datos tiene siete dimensiones:
#
# 1) Contaminante atmosférico [AIRPOL]: Se presentan los resultados de 14 emisiones atmosféricas, a saber:
#
# dióxido de carbono (CO2)
# hidrofluorocarburos en equivalentes de CO2 (HFC_CO2E)
# metano (CH4)
# perfluorocarbonos en equivalentes de CO2 (PFC_CO2E)
# óxido nitroso (N2O)
# óxidos de azufre (SOX) en equivalentes de dióxido de azufre (SO2) (SOX_SO2E)
# amoníaco (NH3)
# óxidos de nitrógeno (NOX) en equivalentes de dióxido de nitrógeno (NO2) (NOX_SO2E)
# monóxido de carbono (CO)
# compuestos orgánicos volátiles no metanos (COVNM)
# material particulado < 10 μm (PM10)
# material particulado < 2,5 μm (PM2_5)
# trifluoruro de nitrógeno y hexafluoruro de azufre en equivalentes de CO2 (NF3_SF6_CO2E)
# [notificados conjuntamente] De estas emisiones atmosféricas, el dióxido de carbono, el metano, el óxido nitroso, los hidrofluorocarbonos, los perfluorocarbonos, el trifluoruro de nitrógeno y el hexafluoruro de azufre son gases de efecto invernadero.
# Además, el conjunto de datos incluye varios contaminantes atmosféricos expresados en equivalentes de otro contaminante atmosférico:
#
# CH4 en equivalentes de CO2 (CH4_CO2E)(*)
#
# N2O en equivalentes de CO2 (N2O_CO2E)
#
# NH3 en SO2 equivalentes (NH3_SO2E)(*)
#
# NOX en SO2 equivalentes (NOX_SO2E)
#
# NOX en equivalentes de COVNM (NOX_NMVOCE)
#
# CO en equivalentes de COVNM (CO_NMVOCE)
#
# CH4 en equivalentes de COVNM (CH4_NMVOCE) (*) Los valores potenciales de calentamiento global utilizados para expresar CH4 y N2O en equivalentesde CO 2 son 25 y 298, respectivamente. Véase el cuadro 2.14 del cuarto informe de evaluación del IPCC (AR4 Climate Change 2007: The Physical Science Basis - Chapter 2, Changes in atmospheric constituents and in radiative forcing). Los contaminantes atmosféricos expresados en equivalentes de otros contaminantes atmosféricos permiten calcular las siguientes presiones ambientales:
#
# Presión ambiental: Potencial de calentamiento global
#
# Código: GEI
#
# Cálculo: CO2 + N2O en CO2 eq. + CH4 en CO2 eq. + HFC en CO2 eq. + PFC en CO2 eq.+ NF3 y SF6 en CO2 eq.
#
# Presión ambiental: Acidificación
#
# Código: ACG
#
# Cálculo: SOX en SO2 eq. + NOX en SO2 eq. + NH3 en SO2 eq.
#
# Presión ambiental: Precursores del ozono troposférico
#
# Código: O3PR
#
# Cálculo: NMVOC + NOX en NMVOC eq + CO en NMVOC eq. + CH4 en NMVOC eq.
#
# Obsérvese que en ciertos casos los gases fluorados (HFC, PFC, NF3 y SF6) han sido colmados por Eurostat.
#
# 2) Clasificación estadística de productos por actividad en la Comunidad Económica Europea, versión 2008 [CPA08]: Los productos para uso final, para los que se estiman y presentan las emisiones atmosféricas «incorporadas», se clasifican de acuerdo con la clasificación CPA 2008. El nivel de desagregación del producto es principalmente el nivel de 2 dígitos; en total, 64 grupos de productos. Además, se reportan las emisiones directas de los hogares privados.
#
# 3) Entidad geopolítica (informes) [GEO]: Unión Europea
#
# 4) Lugar de origen [ORIGEN]: El lugar de donde se supone que procede la emisión atmosférica "incorporada" estimada. Tres valores son posibles:
#
# DOM = «economía doméstica», es decir, se supone que las emisiones se originan en las actividades económicas nacionales (producción y consumo). ROW = «Resto del mundo (estimado: suponiendo tecnologías nacionales)», es decir, se supone que las emisiones proceden del resto de las economías mundiales; por la que se aplica el llamado «supuesto de tecnología nacional». WORLD = 'Total', es decir, la suma de los dos anteriores.
#
# 5) Período de tiempo [TIME]: los datos son anuales. 6) Columnas [INDUSE]: Esta dimensión da cabida a las diversas categorías de cuentas nacionales de «uso final», una clasificación de columnas específica aplicada en tablas simétricas input-output y tablas de uso. En un primer nivel de desagregación, el "uso final" total incluye:
#
# Gastos de consumo final (por hogares, gobierno, etc.);
#
# Formación bruta de capital (principalmente bienes de inversión utilizados para la formación de capital, como, por ejemplo, edificios, equipos de maquinaria, etc.); Exportaciones (es decir, bienes y servicios vendidos a otras economías del resto del mundo). Obsérvese que el concepto «huella» generalmente capta las emisiones causadas por la demanda final interna en la economía de referencia; en otras palabras, causada por el gasto en consumo final y la formación bruta de capital. Las emisiones incorporadas en las exportaciones de la UE cuentan para la huella de otros países y se excluyen de la huella de la UE.
#
# 7) Unidad [UNIT]: toneladas, miles de toneladas y kilogramos per cápita.

# %% [markdown]
# ***Primero cargo las librerías a utilizar para poder analizar y trabajar los datos. A posterior cargo la base de datos:***

# %%
import pandas as pd

#Emisiones Gaseosas UE28.csv
urlDatasetDos= "https://drive.google.com/file/d/1VS0F_r00HRoYudt1EbkB_iR-WV6JD1nF/view?usp=sharing"
urlDatasetDos= "https://drive.google.com/uc?id=" + urlDatasetDos.split('/')[-2]

emisiones = pd.read_csv(urlDatasetDos, sep=",")

emisiones
# Out:
#           airpol    cpa08 induse origin    unit geo\time         2018  \
# 0            ACG  CPA_A01     P3    DOM  KG_HAB     EU28        3.952
# 1            ACG  CPA_A01     P3    DOM       T     EU28  2027709.000
# 2            ACG  CPA_A01     P3    DOM   THS_T     EU28     2027.709
# 3            ACG  CPA_A01     P3    ROW  KG_HAB     EU28        0.932
# 4            ACG  CPA_A01     P3    ROW       T     EU28   477994.000
# ...          ...      ...    ...    ...     ...      ...          ...
# 173659  SOX_SO2E   TOT_HH    TFU    ROW       T     EU28   813364.000
# 173660  SOX_SO2E   TOT_HH    TFU    ROW   THS_T     EU28      813.364
# 173661  SOX_SO2E   TOT_HH    TFU  WORLD  KG_HAB     EU28        7.610
# 173662  SOX_SO2E   TOT_HH    TFU  WORLD       T     EU28  3904382.000
# 173663  SOX_SO2E   TOT_HH    TFU  WORLD   THS_T     EU28     3904.382
#
#                2017         2016         2015         2014         2013  \
# ...

# %% [markdown]
# ***Luego analicé los tipos de datos:***

# %%
emisiones.dtypes
# Out:
# airpol       object
# cpa08        object
# induse       object
# origin       object
# unit         object
# geo\time     object
# 2018        float64
# 2017        float64
# 2016        float64
# 2015        float64
# 2014        float64
# 2013        float64
# 2012        float64
# 2011        float64
# 2010        float64
# 2009        float64
# 2008        float64
# dtype: object

# %% [markdown]
# ***Analizo la cantidad de elementos nulos por columnas:***

# %%
emisiones.isnull().sum()
# Out:
# airpol      0
# cpa08       0
# induse      0
# origin      0
# unit        0
# geo\time    0
# 2018        0
# 2017        0
# 2016        0
# 2015        0
# 2014        0
# 2013        0
# 2012        0
# 2011        0
# 2010        0
# 2009        0
# 2008        0
# dtype: int64

# %%
emisiones.isna().sum()
# Out:
# airpol      0
# cpa08       0
# induse      0
# origin      0
# unit        0
# geo\time    0
# 2018        0
# 2017        0
# 2016        0
# 2015        0
# 2014        0
# 2013        0
# 2012        0
# 2011        0
# 2010        0
# 2009        0
# 2008        0
# dtype: int64

# %% [markdown]
# ***Utilizo el método .groupby() para calcular la media anual para cada contaminante:***

# %%
Emisiones=emisiones.groupby('airpol')[['2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']].mean()
Emisiones
# Out:
#                           2008          2009          2010          2011  \
# airpol
# ACG               8.713319e+04  7.701501e+04  7.536917e+04  7.470875e+04
# CH4               9.146024e+04  8.339327e+04  8.383308e+04  8.523814e+04
# CH4_CO2E          2.286506e+06  2.084832e+06  2.095827e+06  2.130953e+06
# CH4_NMVOCE        1.280443e+03  1.167507e+03  1.173662e+03  1.193331e+03
# CO                8.246882e+04  7.155436e+04  7.539416e+04  6.979793e+04
# CO2               1.551483e+07  1.363721e+07  1.423417e+07  1.393738e+07
# CO2_N2O_CH4_CO2E  1.880643e+07  1.663714e+07  1.721826e+07  1.695629e+07
# CO_NMVOCE         9.071565e+03  7.870979e+03  8.293359e+03  7.677774e+03
# GHG               1.918184e+07  1.699333e+07  1.760378e+07  1.734888e+07
# HFC_CO2E          3.244573e+05  3.183110e+05  3.449802e+05  3.519670e+05
# N2O               3.372803e+03  3.070794e+03  2.980751e+03  2.979703e+03
# N2O_CO2E          1.005097e+06  9.150971e+05  8.882642e+05  8.879521e+05
# ...

# %% [markdown]
# **Configuro algunas variables para determinar porcentajes de reducción entre los años seleccionados:**

# %%
data = Emisiones['2008']
data
# Out:
# airpol
# ACG                 8.713319e+04
# CH4                 9.146024e+04
# CH4_CO2E            2.286506e+06
# CH4_NMVOCE          1.280443e+03
# CO                  8.246882e+04
# CO2                 1.551483e+07
# CO2_N2O_CH4_CO2E    1.880643e+07
# CO_NMVOCE           9.071565e+03
# GHG                 1.918184e+07
# HFC_CO2E            3.244573e+05
# N2O                 3.372803e+03
# N2O_CO2E            1.005097e+06
# NF3_SF6_CO2E        2.647883e+04
# NH3                 1.486357e+04
# NH3_SO2E            2.824080e+04
# NMVOC               3.307577e+04
# NOX                 4.830250e+04
# NOX_NMVOCE          5.892906e+04
# NOX_SO2E            3.381175e+04
# O3PR                1.023568e+05
# PFC_CO2E            2.446870e+04
# PM10                9.644282e+03
# PM2_5               5.569411e+03
# SOX_SO2E            2.508064e+04
# Name: 2008, dtype: float64

# %%
data2 = Emisiones['2018']
data2
# Out:
# airpol
# ACG                 6.137919e+04
# CH4                 7.271876e+04
# CH4_CO2E            1.817969e+06
# CH4_NMVOCE          1.018058e+03
# CO                  5.781706e+04
# CO2                 1.248424e+07
# CO2_N2O_CH4_CO2E    1.518633e+07
# CO_NMVOCE           6.359873e+03
# GHG                 1.555869e+07
# HFC_CO2E            3.328924e+05
# N2O                 2.966814e+03
# N2O_CO2E            8.841117e+05
# NF3_SF6_CO2E        2.482631e+04
# NH3                 1.451140e+04
# NH3_SO2E            2.757167e+04
# NMVOC               2.583789e+04
# NOX                 3.334970e+04
# NOX_NMVOCE          4.068664e+04
# NOX_SO2E            2.334479e+04
# O3PR                7.390248e+04
# PFC_CO2E            1.464936e+04
# PM10                7.017091e+03
# PM2_5               3.999951e+03
# SOX_SO2E            1.046273e+04
# Name: 2018, dtype: float64

# %% [markdown]
# **Porcentajes de Reducción:**

# %%
Porcentaje=(((data-data2)*100)/data)
Porcentaje
# Out:
# airpol
# ACG                 29.557051
# CH4                 20.491396
# CH4_CO2E            20.491390
# CH4_NMVOCE          20.491695
# CO                  29.892214
# CO2                 19.533487
# CO2_N2O_CH4_CO2E    19.249314
# CO_NMVOCE           29.892223
# GHG                 18.888420
# HFC_CO2E            -2.599753
# N2O                 12.037152
# N2O_CO2E            12.037152
# NF3_SF6_CO2E         6.240911
# NH3                  2.369349
# NH3_SO2E             2.369355
# NMVOC               21.882716
# NOX                 30.956576
# NOX_NMVOCE          30.956576
# NOX_SO2E            30.956577
# O3PR                27.799184
# PFC_CO2E            40.130207
# PM10                27.240917
# PM2_5               28.180012
# SOX_SO2E            58.283654
# dtype: float64

# %% [markdown]
# **Máxima y Mínima reducción**

# %%
Porcentaje.max()
# Out:
# 58.283653521372905

# %%
Porcentaje.min()
# Out:
# -2.5997530073820174

# %% [markdown]
# **Reducción promedio:**

# %%
Porcentaje.mean()
# Out:
# 22.38865722844744

# %% [markdown]
# ***Cargo librerías para graficar:***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ***Gráficos Matplotlib:***

# %% [markdown]
# *Gráfico de Línea:*

# %%
fig, ax= plt.subplots(figsize=(10,6))

ax.plot(Emisiones.iloc[16],
        label='NOX',
        linewidth=2)

ax.legend()
ax.grid()

ax.set_title('Evolución de los Óxidos de Nitrógeno')
ax.set_xlabel('Años')
ax.set_ylabel('Valor')

plt.show();

# %% [markdown]
# Este gráfico evidencia como fue decayendo la emisión del contaminante con los años. Se puede tomar como un logro de las políticas medioambientales aplicadas para tal fin.
# NOx es una abreviatura para óxidos de nitrógeno. Estos compuestos son un subproducto de la combustión a altas temperaturas y se forman en todas las combustiones llevadas a cabo a altas temperaturas. Los motores diésel son los que más NOx y subproductos generan en la combustión y por tanto son los coches más contaminantes en lo que se refiere a la salud para las personas. Los NOx son moléculas que forman partículas sólidas muy finas, menores a 0,3 micrones, que se encuentran en la famosa nube de smog de las ciudades, son nocivas para la salud y dañan la calidad del aire.

# %% [markdown]
# *Graficando la evolución del Dióxido de Carbono:*

# %%
fig, ax= plt.subplots(figsize=(10,6))

ax.plot(Emisiones.iloc[5],
        label='CO2',
        linewidth=1.75,
        color="orange")
ax.legend()
ax.grid()

ax.set_title('Evolución del Dióxido de Carbono')
ax.set_xlabel('Años')
ax.set_ylabel('Valor')

plt.show();

# %% [markdown]
# Mismo caso que el anterior. La caída abrupta luego de 2008 puede ser explicada por la recesión provocada por la crisis subprime.
# Este gas es uno de los responsables del llamado efecto invernadero, un fenómeno necesario para la vida en la Tierra pero que tiene efectos muy perjudiciales si se pierde el delicado equilibrio en el que se sustenta.

# %% [markdown]
# *Histograma:*

# %%
fig, ax = plt.subplots(figsize=(8, 4))

ax.hist(Emisiones.iloc[23], color="green")

ax.set_title('Evolución del PM 2,5')

plt.show();

# %% [markdown]
# Un histograma es una representación gráfica de una variable en forma de barras, donde la superficie de cada barra es proporcional a la frecuencia de los valores representados. Sirve para obtener una "primera vista" general, o panorama, de la distribución de la población, o de la muestra, respecto a una característica, cuantitativa y continua.
# En este caso la variable es el PM2.5. son partículas finas con un diámetro de 2.5 micrómetros o menos. Estas partículas pueden ser inhaladas profundamente en los pulmones y causar problemas de salud. Las fuentes de PM2.5 incluyen la quema de combustibles fósiles, la producción de energía y la quema de biomasa. La exposición a largo plazo a PM2.5 puede causar enfermedades respiratorias y cardiovasculares, así como cáncer de pulmón.

# %% [markdown]
# *Boxplot:*

# %%
fig, ax = plt.subplots(figsize=(9, 5))

ax.boxplot(Emisiones.iloc[1])

ax.set_title('Valores del Metano')
ax.set_ylabel('Valores')

plt.show();

# %% [markdown]
# Este gráfico muestra el valor de la mediana en la línea naranja, además muestra entre que valores se situan mayormente los datos evidenciado por el rectángulo y sus outliers en los extremos.
# El metano es un gas de efecto invernadero que contamina mucho más que el dióxido de carbono (CO2), además es responsable de más del 25% del calentamiento que estamos experimentando actualmente. Es el principal contribuyente a la formación de ozono a nivel del suelo, un contaminante atmosférico peligroso. Representa casi una quinta parte de las emisiones globales de gases de efecto invernadero.

# %% [markdown]
# ***Gráficos Seaborn:***

# %% [markdown]
# *Countplot:*

# %%
sns.countplot(x=['2018','2013','2008'], data=Emisiones.iloc[21])
plt.show();

# %% [markdown]
# Un countplot es un tipo de gráfico que muestra los recuentos de observaciones en cada contenedor categórico usando barras. En este caso al haber o existir una observación por cada año solamente muestra una barra por año seleccionado, esta barra representa la media anual de dicho año seleccionado, la unidad de la misma son toneladas. Se eligieron los años 2008, 2013 y 2018. En este caso el contaminante es el PM10 que son partículas finas con un diámetro de 10 micrómetros o menos. Estas partículas pueden ser inhaladas profundamente en los pulmones y causar problemas de salud. Las fuentes de PM10 incluyen la quema de combustibles fósiles, la producción de energía y la quema de biomasa. La exposición a largo plazo a PM10 puede causar enfermedades respiratorias y cardiovasculares, así como cáncer de pulmón.

# %% [markdown]
# *Barplot:*

# %%
sns.barplot(data=Emisiones)
# Out:
# <Axes: >

# %% [markdown]
# Un gráfico de barras es un gráfico que representa la categoría de datos con barras rectangulares con longitudes y alturas que son proporcionales a los valores que representan. En este caso, se analizan todas las emisiones por año, y como se viene observando anteriormente se produce la caída en las mismas post 2008 (subprimer-recesión), luego tienen un rebote (2009-2010) para continuar descendiendo.

# %% [markdown]
# *Boxplot:*

# %%
sns.boxplot(data=Emisiones.iloc[19])
# Out:
# <Axes: >

# %% [markdown]
# Un diagrama de caja es un método para demostrar gráficamente la localidad, la dispersión y los grupos de asimetría de datos numéricos a través de sus cuartiles. Un diagrama de caja es una forma estandarizada de mostrar el conjunto de datos basado en el resumen de cinco números: el mínimo, el máximo, la mediana de la muestra, el primer y tercer cuartiles.
# Este gráfico analiza la variación del Ozono troposférico, el cual es un contaminante secundario, es el compuesto más representativo de los oxidantes fotoquímicos y uno de los principales ingredientes del smog urbano.

# %% [markdown]
# *Matriz de Correlación*

# %%
Emisiones.corr()
# Out:
#           2008      2009      2010      2011      2012      2013      2014  \
# 2008  1.000000  0.999990  0.999997  0.999990  0.999979  0.999977  0.999944
# 2009  0.999990  1.000000  0.999987  0.999997  0.999996  0.999994  0.999980
# 2010  0.999997  0.999987  1.000000  0.999992  0.999982  0.999982  0.999947
# 2011  0.999990  0.999997  0.999992  1.000000  0.999998  0.999996  0.999977
# 2012  0.999979  0.999996  0.999982  0.999998  1.000000  0.999999  0.999989
# 2013  0.999977  0.999994  0.999982  0.999996  0.999999  1.000000  0.999991
# 2014  0.999944  0.999980  0.999947  0.999977  0.999989  0.999991  1.000000
# 2015  0.999970  0.999991  0.999972  0.999989  0.999995  0.999998  0.999994
# 2016  0.999981  0.999985  0.999983  0.999983  0.999980  0.999986  0.999968
# 2017  0.999981  0.999986  0.999982  0.999983  0.999981  0.999987  0.999971
# 2018  0.999984  0.999988  0.999984  0.999984  0.999982  0.999987  0.999970
#
#           2015      2016      2017      2018
# ...

# %% [markdown]
# *Una matriz de correlación brinda información sobre la intensidad y la dirección de la relación lineal entre dos o más variables. Es decir, indica cómo varía una variable cuando cambia otra, y si esa variación es positiva o negativa.*

# %% [markdown]
# *Heatmap*

# %%
plt.figure(figsize=(10,6))
cmap = plt.cm.get_cmap("Greens")
cmap.set_over("#139874")
sns.heatmap(data=Emisiones.corr(), cmap=cmap)
plt.show();
# Out:
# <ipython-input-21-78c101d791f7>:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap("Greens")

# %% [markdown]
# *El heatmap muestra la correlación entre las variables del dataframe Emisiones, usando una escala de colores que va del verde oscuro al blanco, donde el verde oscuro representa una correlación positiva alta y el blanco una correlación negativa alta.*

# %% [markdown]
# **Para poder avanzar con las Herramientas de visualización y Preprocesamiento estadístico de los datos realizo las siguientes acciones sobre el dataset original:**

# %%
urlDatasetDos= "https://drive.google.com/file/d/1VS0F_r00HRoYudt1EbkB_iR-WV6JD1nF/view?usp=sharing"
urlDatasetDos= "https://drive.google.com/uc?id=" + urlDatasetDos.split('/')[-2]

df_emissions = pd.read_csv(urlDatasetDos, sep=",")
df_emissions.drop('geo\\time', axis='columns', inplace=True)
df_emissions.index = df_emissions['airpol']
df_emissions.drop('airpol', axis='columns', inplace=True)
df_emissions
# Out:
#             cpa08 induse origin    unit         2018         2017  \
# airpol
# ACG       CPA_A01     P3    DOM  KG_HAB        3.952        4.034
# ACG       CPA_A01     P3    DOM       T  2027709.000  2065165.000
# ACG       CPA_A01     P3    DOM   THS_T     2027.709     2065.165
# ACG       CPA_A01     P3    ROW  KG_HAB        0.932        0.930
# ACG       CPA_A01     P3    ROW       T   477994.000   476142.000
# ...           ...    ...    ...     ...          ...          ...
# SOX_SO2E   TOT_HH    TFU    ROW       T   813364.000   834092.000
# SOX_SO2E   TOT_HH    TFU    ROW   THS_T      813.364      834.092
# SOX_SO2E   TOT_HH    TFU  WORLD  KG_HAB        7.610        7.914
# SOX_SO2E   TOT_HH    TFU  WORLD       T  3904382.000  4051619.000
# SOX_SO2E   TOT_HH    TFU  WORLD   THS_T     3904.382     4051.619
#
#                  2016         2015         2014         2013         2012  \
# airpol
# ACG             3.952        3.901        3.824        4.182        4.260
# ...

# %% [markdown]
# **A continuación filtro la cantidad total de emisiones domésticas (cantidades nacionales de cada contaminante por año en KG/HAB):**

# %%
df_emissionsFiltered = df_emissions[(df_emissions.cpa08 == 'TOTAL')&(df_emissions.induse == 'TFU')&(df_emissions.origin == 'DOM')&(df_emissions.unit == 'KG_HAB')]
df_view = df_emissionsFiltered.drop(['cpa08','induse', 'origin','unit'], axis='columns')
df_view
# Out:
#                       2018      2017      2016      2015      2014      2013  \
# airpol
# ACG                 30.795    31.425    33.049    32.930    33.384    34.375
# CH4                 33.004    33.548    34.875    34.159    34.310    34.853
# CH4_CO2E           825.100   838.705   871.867   853.966   857.742   871.320
# CH4_NMVOCE           0.462     0.470     0.488     0.478     0.480     0.488
# CO                  16.290    16.669    17.958    17.119    16.921    18.258
# CO2               5511.029  5629.811  5905.435  5717.240  5691.148  5926.620
# CO2_N2O_CH4_CO2E  6775.482  6917.710  7240.597  7015.328  6995.524  7240.390
# CO_NMVOCE            1.792     1.834     1.975     1.883     1.861     2.008
# GHG               6951.702  7103.394  7433.598  7209.755  7197.969  7440.605
# HFC_CO2E           156.500   166.364   172.609   176.237   185.007   181.585
# N2O                  1.474     1.507     1.555     1.490     1.499     1.485
# ...

# %% [markdown]
# **Luego sigo trabajando con la matriz para resolver las preguntas que me llevó a elegir este set de datos:**

# %%
df_emissionsFiltered = df_emissions[(df_emissions.cpa08 == 'TOTAL')&(df_emissions.induse == 'TFU')&(df_emissions.origin == 'DOM')&(df_emissions.unit == 'KG_HAB')]
df_view = df_emissionsFiltered.drop(['cpa08','induse', 'origin','unit'], axis='columns')
df_view = df_view.T
df_view = df_view.rename_axis(None, axis=1)
df_view = df_view.sort_index()
df_view
# Out:
#          ACG     CH4  CH4_CO2E  CH4_NMVOCE      CO       CO2  \
# 2008  44.420  38.927   973.171       0.545  23.237  6965.956
# 2009  40.065  37.861   946.517       0.530  19.500  6237.290
# 2010  38.572  36.854   921.358       0.516  20.950  6402.864
# 2011  38.043  36.242   906.048       0.507  19.894  6256.945
# 2012  36.447  35.881   897.022       0.502  18.000  6128.093
# 2013  34.375  34.853   871.320       0.488  18.258  5926.620
# 2014  33.384  34.310   857.742       0.480  16.921  5691.148
# 2015  32.930  34.159   853.966       0.478  17.119  5717.240
# 2016  33.049  34.875   871.867       0.488  17.958  5905.435
# 2017  31.425  33.548   838.705       0.470  16.669  5629.811
# 2018  30.795  33.004   825.100       0.462  16.290  5511.029
#
#       CO2_N2O_CH4_CO2E  CO_NMVOCE       GHG  HFC_CO2E  ...  NH3_SO2E   NMVOC  \
# 2008          8449.787      2.556  8629.442   155.960  ...    14.251  12.549
# ...

# %% [markdown]
# **Con la siguiente visualización univariada (gráfico de línea) busco entender la evolución de las emisiones de CO2 en el tiempo ¿Crecieron o disminuyeron?, además en gráficos posteriores voy a analizar otros contaminantes:**

# %%
x = df_view.index
CO2 = df_view.CO2

fig, ax = plt.subplots(figsize=(8,4))

ax.plot(x,CO2,label = 'CO2',color="red")

ax.set_xlabel('Año')
ax.set_ylabel('KG/HAB')
ax.set_title('Evolución del Dióxido de Carbono en el tiempo')
ax.set_xlim(df_view.index[0], df_view.index[-1])
ax.legend()

# %% [markdown]
# Se puede apreciar que las mismas han disminuido, lo cuál es muy bueno.

# %% [markdown]
# **A continuación en una visualización univariada (histograma) se puede observar que otro contaminante criterio como el NOx también se encuentra en retroceso:**

# %%
x = df_view.index
NOX = df_view.NOX
fig, ax = plt.subplots(figsize=(8, 4))

ax.hist(df_view.NOX,color="brown")

ax.set_title('Evolución del NOx')

plt.show();

# %% [markdown]
# **Una visualización bivariada (boxplot) se observan los rangos entre los que se movió el metano en los años estudiados:**

# %%
x = df_view.index
CH4 = df_view.CH4
fig, ax = plt.subplots(figsize=(8, 4))

ax.boxplot(df_view.CH4)

ax.set_title('Valores del Metano')
ax.set_ylabel('KG/HAB')

plt.show();

# %% [markdown]
# **En la siguiente visualización bivariada (diagrama de dispersión) se puede observar que el monóxido de carbono sigue la tendencia descendente al igual que los otros gases analizados:**

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
CO=df_view.CO
sns.scatterplot(x=df_view.index, y= CO, size= CO, color="green")
plt.title('Evolución del Monóxido de Carbono')
plt.xlabel('Años')
plt.ylabel('KG/HAB')
# Out:
# Text(0, 0.5, 'KG/HAB')

# %% [markdown]
# **Selección Iterativa:**
#
# *Estos métodos comienzan con un conjunto completo de características y, en cada iteración, eliminan o agregan características en función del rendimiento del modelo. Ejemplos de esto incluyen el algoritmo "Forward Selection" (Selección hacia adelante) y "Backward Elimination" (Eliminación hacia atrás).*

# %% [markdown]
# **Forward Selection:**

# %%
import statsmodels.api as sm
def forward_selection(data, target, significance_level=0.01):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

# %% [markdown]
# *Forward selection es un tipo de regresión paso a paso que comienza con un modelo vacío y agrega variables una por una. En cada paso hacia adelante, se agrega la variable que brinda la mejor mejora única a su modelo. Es uno de los dos métodos comúnmente utilizados de regresión paso a paso; el otro es la eliminación hacia atrás y es casi lo opuesto.*

# %% [markdown]
# **Backward Selection:**

# %%
def backward_elimination(data, target,significance_level = 0.05):
    features = data.columns.tolist()
    while(len(features)>0):
        features_with_constant = sm.add_constant(data[features])
        p_values = sm.OLS(target, features_with_constant).fit().pvalues[1:]
        max_p_value = p_values.max()
        if(max_p_value >= significance_level):
            excluded_feature = p_values.idxmax()
            features.remove(excluded_feature)
        else:
            break
    return features

# %% [markdown]
# *La eliminación hacia atrás es un método de regresión paso a paso que comienza con un modelo que contiene todas las variables y elimina variables una por una. En cada paso hacia atrás, se elimina la variable que brinda la peor mejora única a su modelo. Es uno de los dos métodos comúnmente utilizados de regresión paso a paso; el otro es la selección hacia adelante.*

# %% [markdown]
# **Eliminación bidireccional (stepwise):**

# %%
def stepwise_selection(data, target,SL_in=0.05,SL_out = 0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]])).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<SL_in):
            best_features.append(new_pval.idxmin())
            while(len(best_features)>0):
                best_features_with_constant = sm.add_constant(data[best_features])
                p_values = sm.OLS(target, best_features_with_constant).fit().pvalues[1:]
                max_p_value = p_values.max()
                if(max_p_value >= SL_out):
                    excluded_feature = p_values.idxmax()
                    best_features.remove(excluded_feature)
                else:
                    break
        else:
            break
    return best_features

# %% [markdown]
# *La eliminación bidireccional es un método de regresión paso a paso que combina la selección hacia adelante y la eliminación hacia atrás. Comienza con un modelo vacío y agrega variables una por una. En cada paso hacia adelante, se agrega la variable que brinda la mejor mejora única a su modelo. En cada paso hacia atrás, se elimina la variable que brinda la peor mejora única a su modelo. Es uno de los dos métodos comúnmente utilizados de regresión paso a paso; el otro es la selección hacia adelante y la eliminación hacia atrás.*

# %% [markdown]
# **Algoritmos de Regresión:**
#
# *Los algoritmos de regresión se utilizan para predecir valores numéricos continuos, es decir, para problemas de regresión.*

# %% [markdown]
# **Modelo de regresión lineal:**

# %%
from sklearn import linear_model

# %%
X = Emisiones.iloc[:,:11]
y = Emisiones.iloc[:,:11]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
mi_modelo = linear_model.LinearRegression()

# %%
mi_modelo
# Out:
# LinearRegression()

# %%
mi_modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(mi_modelo.coef_)
# Out:
# [[ 1.00000000e+00  1.76407233e-12 -6.40729863e-13 -1.64306025e-12
#    1.88608602e-12  2.62345113e-12  4.32132177e-13 -5.88382590e-12
#    2.92116600e-12 -5.27021506e-13 -8.80645858e-14]
#  [-8.25221026e-16  1.00000000e+00 -1.05471187e-15 -4.99600361e-16
#    5.55111512e-17  1.66533454e-15 -1.33226763e-15  7.21644966e-16
#   -1.66533454e-16  8.88178420e-16 -1.11022302e-15]
#  [ 3.31113426e-16  4.55191440e-15  1.00000000e+00 -3.35842465e-15
#   -2.62290190e-15  1.28785871e-14 -9.39526235e-15  3.76088050e-15
#   -1.22124533e-15  9.43689571e-16 -1.83186799e-15]
#  [ 5.82232881e-16 -8.32667268e-16 -4.85722573e-16  1.00000000e+00
#   -5.55111512e-16  7.91033905e-16  3.19189120e-16  9.71445147e-17
#    8.60422844e-16  0.00000000e+00 -1.58206781e-15]
#  [-1.35653499e-15  1.77635684e-15 -4.71844785e-16  9.57567359e-16
#    1.00000000e+00  2.52575738e-15 -2.08166817e-16 -1.70696790e-15
#    9.02056208e-16  2.63677968e-16 -2.63677968e-16]
# ...

# %%
y_estimado = mi_modelo.predict(X_test)

# %%
y_estimado
# Out:
# array([[   1280.44284619,    1167.50681965,    1173.6620908 ,
#            1193.33061982,    1180.27789165,    1134.25157352,
#            1117.0350485 ,    1082.92405846,    1052.28296296,
#            1033.82944058,    1018.05839967],
#        [  25080.64187106,   20125.74274143,   18796.05815175,
#           18474.11374613,   16591.61171434,   14408.64958734,
#           13284.54640754,   12317.05732311,   11130.87906772,
#           10915.73290382,   10462.727462  ],
#        [  48302.50299931,   42687.35867455,   42264.39253994,
#           41247.89333002,   39632.45302805,   37421.99709729,
#           36346.14286097,   35761.02795384,   35573.10638157,
#           33980.35690147,   33349.70187217],
#        [1005096.73029533,  915097.09733375,  888264.20384204,
#          887952.07525332,  882315.42349019,  873347.09251299,
#          883988.98516169,  880270.46672222,  913804.84449364,
#          898786.62667068,  884111.71386719],
# ...

# %%
from sklearn.metrics import r2_score

# %%
mi_r2 = r2_score(y_test, y_estimado)

# %%
mi_r2
# Out:
# 1.0

# %%
mi_r2 = mi_modelo.score(X_test, y_test)

# %%
mi_r2
# Out:
# 1.0

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_estimado, color='orange', linewidth=3)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test,y_estimado))
# Out:
# MAE 2.029543628106529e-09

# %% [markdown]
# *Error Medio Absoluto (MAE):*
#
# *Mide el promedio de las diferencias absolutas entre las
# predicciones del modelo y los valores reales.*

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test,y_estimado))
# Out:
# MSE 6.095688972046961e-18

# %% [markdown]
# *Error Cuadrático Medio (MSE):*
#
# *Calcula el promedio de los errores al cuadrado entre las
# predicciones del modelo y los valores reales.*

# %%
import numpy as np

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_estimado)))
# Out:
# RMSE 2.4689449106950444e-09

# %% [markdown]
# *Raíz del Error Cuadrático Medio (RMSE):*
#
# *Es la raíz cuadrada del MSE y proporciona
# una medida en la misma escala que la variable objetivo original.*

# %%
print("RMSE",np.log(np.sqrt(mean_squared_error(y_test,y_estimado))))
# Out:
# RMSE -19.819474939227984

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_estimado)
print(r2)
# Out:
# 1.0

# %% [markdown]
# *Coeficiente de Determinación (R²):*
#
# *Mide la proporción de la varianza de la variable objetivo que es explicada por el modelo.*

# %% [markdown]
# **Modelo de Regresión Múltiple:**

# %%
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
lr = linear_model.LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
lr.score(X_test, y_test)
# Out:
# 1.0

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='green', linewidth=3)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 1.4422069503076126e-16

# %% [markdown]
# *Error Cuadrático Medio (MSE):*
#
# *Calcula el promedio de los errores al cuadrado entre las
# predicciones del modelo y los valores reales.*

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 1.200919210566478e-08

# %% [markdown]
# *Raíz del Error Cuadrático Medio (RMSE):*
#
# *Es la raíz cuadrada del MSE y proporciona
# una medida en la misma escala que la variable objetivo original.*

# %%
print("RMSE",np.log(np.sqrt(mean_squared_error(y_test,y_pred))))
# Out:
# RMSE -18.23759347158802

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 1.0

# %% [markdown]
# *Coeficiente de Determinación (R²):*
#
# *Mide la proporción de la varianza de la variable objetivo que es explicada por el modelo.*

# %% [markdown]
# **Como podemos observar que ambos modelos se ajustan bien aunque el de regresión múltiple tiene mejores métricas.**
#
# **En ambos modelos tenemos un caso de overfitting (sobreajuste).**

# %% [markdown]
# **Data Wrangling**

# %% [markdown]
# Instalando el CDSAPI:

# %%
pip install CDSAPI

# %% [markdown]
# A continuación importé las librerías:

# %%
import json
import pandas as pd
import requests

# %% [markdown]
# Para poder hacer el desafío selecciono la siguiente API (https://newsapi.org), buscando noticias sobre cambio climático:

# %%
url='https://newsapi.org/v2/everything?q=change+climate&sortBy=popularity&apiKey=ccb6299426494c4f81780dba824383a3'
df2= requests.get(url)
print(df2)
# Out:
# <Response [200]>

# %% [markdown]
# **¿Se escriben artículos relacionados a esta problemática?**

# %% [markdown]
# La conexión fue exitosa y se encontraron artículos relacionados a esta problemática. Los datos están en formato json.

# %%
print(len(df2.text))
df2.text
# Out:
# 83825
# ...

# %% [markdown]
# Los trabajo:

# %%
texto=df2.text
json.loads(texto)
# Out:
# {'status': 'ok',
#  'totalResults': 14446,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Malak Saleh',
#    'title': 'AI is starting to outperform meteorologists',
#    'description': 'A machine learning-based weather prediction program developed by DeepMind researchers called “GraphCast\r\n” can predict weather variables over the span of 10 days, in under one minute. In a report\r\n, scientists highlight that GraphCast has outperformed traditi…',
#    'url': 'https://www.engadget.com/ai-is-starting-to-outperform-meteorologists-173616631.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/VpavCx9lzoRgde6oDi4Gpw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/eaf5eea0-8312-11ee-be6f-e8f1233db9d2',
#    'publishedAt': '2023-11-14T17:36:16Z',
# ...

# %%
texto
# Out:
# '{"status":"ok","totalResults":14446,"articles":[{"source":{"id":"engadget","name":"Engadget"},"author":"Malak Saleh","title":"AI is starting to outperform meteorologists","description":"A machine learning-based weather prediction program developed by DeepMind researchers called “GraphCast\\r\\n” can predict weather variables over the span of 10 days, in under one minute. In a report\\r\\n, scientists highlight that GraphCast has outperformed traditi…","url":"https://www.engadget.com/ai-is-starting-to-outperform-meteorologists-173616631.html","urlToImage":"https://s.yimg.com/ny/api/res/1.2/VpavCx9lzoRgde6oDi4Gpw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/eaf5eea0-8312-11ee-be6f-e8f1233db9d2","publishedAt":"2023-11-14T17:36:16Z","content":"A machine learning-based weather prediction program developed by DeepMind researchers called GraphCast can predict weather variables over the span of 10 days, in under one minute. In a report, sci
# ...

# %% [markdown]
# Los convierto en una base de datos:

# %%
import json
info = json.loads(texto)
info
# Out:
# {'status': 'ok',
#  'totalResults': 14446,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Malak Saleh',
#    'title': 'AI is starting to outperform meteorologists',
#    'description': 'A machine learning-based weather prediction program developed by DeepMind researchers called “GraphCast\r\n” can predict weather variables over the span of 10 days, in under one minute. In a report\r\n, scientists highlight that GraphCast has outperformed traditi…',
#    'url': 'https://www.engadget.com/ai-is-starting-to-outperform-meteorologists-173616631.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/VpavCx9lzoRgde6oDi4Gpw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2023-11/eaf5eea0-8312-11ee-be6f-e8f1233db9d2',
#    'publishedAt': '2023-11-14T17:36:16Z',
# ...

# %%
info = json.loads(texto)

news = pd.json_normalize(info['articles'])

news.to_csv("news.csv")
news
# Out:
#                    author                                              title  \
# 0             Malak Saleh        AI is starting to outperform meteorologists
# 1             Jim Robbins     California’s Giant Sequoias Are in Big Trouble
# 2            Ben Goldfarb  The Fight Against the Smallmouth Bass Invasion...
# 3              Matt Simon  Here’s How Bad Climate Change Will Get in the ...
# 4         Abigail Bassett           Is AI the answer to sustainable farming?
# ..                    ...                                                ...
# 95        Thomas Macaulay  Bedazzled by big tech, the UK’s AI summit is o...
# 96            S.A. Applin                Over-automation is breaking the web
# 97             Sam Jacobs  A Look at TIME’s Century of Climate Change Cov...
# 98       Associated Press  E.U. Reaches Deal To Cut Highly Polluting Meth...
# 99  CHRISTINA LARSON / AP  Cheetahs Are Shifting Their Hunting to Night t...
#
# ...

# %%
news.shape
# Out:
# (100, 9)

# %%
news.dtypes
# Out:
# author         object
# title          object
# description    object
# url            object
# urlToImage     object
# publishedAt    object
# content        object
# source.id      object
# source.name    object
# dtype: object

# %%
news.describe()
# Out:
#                                   author  \
# count                                 99
# unique                                70
# top     https://www.facebook.com/bbcnews
# freq                                  12
#
#                                               title  \
# count                                           100
# unique                                          100
# top     AI is starting to outperform meteorologists
# freq                                              1
#
#                                               description  \
# count                                                 100
# unique                                                 99
# top     This story was originally published by Grist. ...
# freq                                                    2
#
#                                                       url  \
# count                                                 100
# unique                                                100
# ...

# %%
news.isnull().sum()
# Out:
# author          1
# title           0
# description     0
# url             0
# urlToImage      0
# publishedAt     0
# content         0
# source.id      33
# source.name     0
# dtype: int64

# %% [markdown]
# Elimino las noticias que poseen alguna de las columnas como nulo:

# %%
newsisntnull = news.dropna(subset=["source.id"])

# %%
newsisntnullfinish = newsisntnull.dropna(subset=["author"])

# %%
newsisntnullfinish.isnull().sum()
# Out:
# author         0
# title          0
# description    0
# url            0
# urlToImage     0
# publishedAt    0
# content        0
# source.id      0
# source.name    0
# dtype: int64

# %% [markdown]
# Volviendo a calcular características de la base de datos trabajada:

# %%
newsisntnullfinish.shape
# Out:
# (66, 9)

# %%
newsisntnullfinish.dtypes
# Out:
# author         object
# title          object
# description    object
# url            object
# urlToImage     object
# publishedAt    object
# content        object
# source.id      object
# source.name    object
# dtype: object

# %%
newsisntnullfinish.describe()
# Out:
#                                   author  \
# count                                 66
# unique                                45
# top     https://www.facebook.com/bbcnews
# freq                                  12
#
#                                               title  \
# count                                            66
# unique                                           66
# top     AI is starting to outperform meteorologists
# freq                                              1
#
#                                               description  \
# count                                                  66
# unique                                                 66
# top     A machine learning-based weather prediction pr...
# freq                                                    1
#
#                                                       url  \
# count                                                  66
# unique                                                 66
# ...

# %%
newsisntnullfinish
# Out:
#                    author                                              title  \
# 0             Malak Saleh        AI is starting to outperform meteorologists
# 1             Jim Robbins     California’s Giant Sequoias Are in Big Trouble
# 2            Ben Goldfarb  The Fight Against the Smallmouth Bass Invasion...
# 3              Matt Simon  Here’s How Bad Climate Change Will Get in the ...
# 4         Abigail Bassett           Is AI the answer to sustainable farming?
# ..                    ...                                                ...
# 94        Siôn Geschwindt  140-year-old ocean heat tech could supply isla...
# 95        Thomas Macaulay  Bedazzled by big tech, the UK’s AI summit is o...
# 97             Sam Jacobs  A Look at TIME’s Century of Climate Change Cov...
# 98       Associated Press  E.U. Reaches Deal To Cut Highly Polluting Meth...
# 99  CHRISTINA LARSON / AP  Cheetahs Are Shifting Their Hunting to Night t...
#
# ...

# %%
text2=newsisntnullfinish['author'].str.split()
text2
# Out:
# 0                 [Malak, Saleh]
# 1                 [Jim, Robbins]
# 2                [Ben, Goldfarb]
# 3                  [Matt, Simon]
# 4             [Abigail, Bassett]
#                  ...
# 94            [Siôn, Geschwindt]
# 95            [Thomas, Macaulay]
# 97                 [Sam, Jacobs]
# 98           [Associated, Press]
# 99    [CHRISTINA, LARSON, /, AP]
# Name: author, Length: 66, dtype: object

# %%
from itertools import chain
words = list(chain.from_iterable(text2))
words
# Out:
# ['Malak',
#  'Saleh',
#  'Jim',
#  'Robbins',
#  'Ben',
#  'Goldfarb',
#  'Matt',
#  'Simon',
#  'Abigail',
#  'Bassett',
#  'Tim',
#  'Stevens',
#  'Nilay',
#  'Patel',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'https://www.facebook.com/bbcnews',
#  'Stephen',
#  'Clark',
#  'hgetahun@insider.com',
#  '(Hannah',
#  'Getahun)',
#  'psyme@insider.com',
#  '(Pete',
#  'Syme)',
#  'Michelle',
#  'Mastro',
#  'Kelsey',
#  'Vlamis',
#  'Maiya',
#  'Focht',
#  'Elijah',
#  'McKenzie-Jackson',
#  'Tim',
#  'Paradis',
#  'Maiya',
#  'Focht',
#  'Maiya',
#  'Focht',
#  'Maiya',
#  'Focht,Jenny',
#  'McGrath',
# ...

# %% [markdown]
# Elimino los artículos de la BBC en Facebook:

# %%
newswofbwobbc = newsisntnullfinish.drop(newsisntnullfinish[newsisntnullfinish["author"] == "https://www.facebook.com/bbcnews"
].index)
newswofbwobbc
# Out:
#                                    author  \
# 0                             Malak Saleh
# 1                             Jim Robbins
# 2                            Ben Goldfarb
# 3                              Matt Simon
# 4                         Abigail Bassett
# 5                             Tim Stevens
# 6                             Nilay Patel
# 23                          Stephen Clark
# 25  hgetahun@insider.com (Hannah Getahun)
# 26          psyme@insider.com (Pete Syme)
# 48                        Michelle Mastro
# 49                          Kelsey Vlamis
# 50                            Maiya Focht
# 51                Elijah McKenzie-Jackson
# 52                            Tim Paradis
# 53                            Maiya Focht
# 54                            Maiya Focht
# 55              Maiya Focht,Jenny McGrath
# 56                        Matthew E. Kahn
# 57                            Cork Gaines
# 58                          Kelsey Vlamis
# ...

# %% [markdown]
# **¿Quiénes son los escritores qué escriben sobre cambio climático?**

# %%
escritores=newswofbwobbc.author
escritores
# Out:
# 0                               Malak Saleh
# 1                               Jim Robbins
# 2                              Ben Goldfarb
# 3                                Matt Simon
# 4                           Abigail Bassett
# 5                               Tim Stevens
# 6                               Nilay Patel
# 23                            Stephen Clark
# 25    hgetahun@insider.com (Hannah Getahun)
# 26            psyme@insider.com (Pete Syme)
# 48                          Michelle Mastro
# 49                            Kelsey Vlamis
# 50                              Maiya Focht
# 51                  Elijah McKenzie-Jackson
# 52                              Tim Paradis
# 53                              Maiya Focht
# 54                              Maiya Focht
# 55                Maiya Focht,Jenny McGrath
# 56                          Matthew E. Kahn
# 57                              Cork Gaines
# 58                            Kelsey Vlamis
# ...

# %%
newswofbwobbc.shape
# Out:
# (54, 9)

# %% [markdown]
# **¿Cuántos escritores son?**

# %%
m = sum([newswofbwobbc["author"] != "https://www.facebook.com/bbcnews"])
autores=sum(m)
print(autores)
# Out:
# 54

# %% [markdown]
# Elimino todos los artículos que no son de la BBC en Facebook:

# %%
newswfbwbbc = newsisntnullfinish.drop(newsisntnullfinish[newsisntnullfinish["author"] != "https://www.facebook.com/bbcnews"
].index)
newswfbwbbc
# Out:
#                               author  \
# 9   https://www.facebook.com/bbcnews
# 10  https://www.facebook.com/bbcnews
# 11  https://www.facebook.com/bbcnews
# 12  https://www.facebook.com/bbcnews
# 13  https://www.facebook.com/bbcnews
# 14  https://www.facebook.com/bbcnews
# 15  https://www.facebook.com/bbcnews
# 17  https://www.facebook.com/bbcnews
# 18  https://www.facebook.com/bbcnews
# 19  https://www.facebook.com/bbcnews
# 20  https://www.facebook.com/bbcnews
# 21  https://www.facebook.com/bbcnews
#
#                                                 title  \
# 9   Pope Francis fires Texan bishop after criticis...
# 10  'Virtually certain' that 2023 will be warmest ...
# 11  Argentines choose between polar opposites in r...
# 12  Prince Harry to call as King celebrates his 75...
# 13  Meet the longshot candidates who could swing t...
# 14  Zimbabwe's cholera crisis fuelled by chronic w...
# 15  International mafia bust shows US-Italy crime ...
# ...

# %%
newswfbwbbc.shape
# Out:
# (12, 9)

# %% [markdown]
# **¿Cuántos artículos publica la BBC en Facebook sobre Cambio Climático?**

# %% [markdown]
# Cuento los artículos publicados por la BBC en Facebook:

# %%
n = sum([newswfbwbbc["author"] == "https://www.facebook.com/bbcnews"])
fbbbc=sum(n)
print(fbbbc)
# Out:
# 12

# %%
text3=newswofbwobbc['author'].str.split()
text3
# Out:
# 0                                [Malak, Saleh]
# 1                                [Jim, Robbins]
# 2                               [Ben, Goldfarb]
# 3                                 [Matt, Simon]
# 4                            [Abigail, Bassett]
# 5                                [Tim, Stevens]
# 6                                [Nilay, Patel]
# 23                             [Stephen, Clark]
# 25    [hgetahun@insider.com, (Hannah, Getahun)]
# 26            [psyme@insider.com, (Pete, Syme)]
# 48                           [Michelle, Mastro]
# 49                             [Kelsey, Vlamis]
# 50                               [Maiya, Focht]
# 51                   [Elijah, McKenzie-Jackson]
# 52                               [Tim, Paradis]
# 53                               [Maiya, Focht]
# 54                               [Maiya, Focht]
# 55                [Maiya, Focht,Jenny, McGrath]
# 56                          [Matthew, E., Kahn]
# 57                               [Cork, Gaines]
# ...

# %%
from itertools import chain
words = list(chain.from_iterable(text3))

# %%
text3=newswofbwobbc['author'].str.split()
words2 = np.array(words).flatten().tolist()
text4 = " ".join(words2)
text4
# Out:
# 'Malak Saleh Jim Robbins Ben Goldfarb Matt Simon Abigail Bassett Tim Stevens Nilay Patel Stephen Clark hgetahun@insider.com (Hannah Getahun) psyme@insider.com (Pete Syme) Michelle Mastro Kelsey Vlamis Maiya Focht Elijah McKenzie-Jackson Tim Paradis Maiya Focht Maiya Focht Maiya Focht,Jenny McGrath Matthew E. Kahn Cork Gaines Kelsey Vlamis Grace Eliza Goodwin,Jenny McGrath Ayelet Sheffey Hannah Getahun Hazel Davis Hannah Getahun Jenny McGrath Bryan Metzger Sarah Jackson Tom Porter John L. Dorman Madeline Berg Eliza Relman Adam Rogers Beatrice Nolan Kelsey Vlamis,Hannah Getahun Cork Gaines Tom Porter Alcynna Lloyd,Noah Sheidlower Eliza Relman Jacob Zinkula Bella Sayegh Jenny McGrath Clem De Pressigny Siôn Geschwindt Linnea Ahlgren Siôn Geschwindt Ioanna Lykiardopoulou Andrea Hak Siôn Geschwindt Thomas Macaulay Sam Jacobs Associated Press CHRISTINA LARSON / AP'

# %%
from wordcloud import WordCloud

# %%
text3=newswofbwobbc['author'].str.split()
words2 = np.array(words).flatten().tolist()
text4 = " ".join(words2)
text4
# Out:
# 'Malak Saleh Jim Robbins Ben Goldfarb Matt Simon Abigail Bassett Tim Stevens Nilay Patel Stephen Clark hgetahun@insider.com (Hannah Getahun) psyme@insider.com (Pete Syme) Michelle Mastro Kelsey Vlamis Maiya Focht Elijah McKenzie-Jackson Tim Paradis Maiya Focht Maiya Focht Maiya Focht,Jenny McGrath Matthew E. Kahn Cork Gaines Kelsey Vlamis Grace Eliza Goodwin,Jenny McGrath Ayelet Sheffey Hannah Getahun Hazel Davis Hannah Getahun Jenny McGrath Bryan Metzger Sarah Jackson Tom Porter John L. Dorman Madeline Berg Eliza Relman Adam Rogers Beatrice Nolan Kelsey Vlamis,Hannah Getahun Cork Gaines Tom Porter Alcynna Lloyd,Noah Sheidlower Eliza Relman Jacob Zinkula Bella Sayegh Jenny McGrath Clem De Pressigny Siôn Geschwindt Linnea Ahlgren Siôn Geschwindt Ioanna Lykiardopoulou Andrea Hak Siôn Geschwindt Thomas Macaulay Sam Jacobs Associated Press CHRISTINA LARSON / AP'

# %%
wordcloud = WordCloud(background_color="white").generate(text4)

plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# **Entrenando un algoritmo de Machine Learning**

# %%
from sklearn import linear_model

# %%
X = Emisiones.iloc[:,:5000]
y = Emisiones.iloc[:,:5000]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
mi_modelo = linear_model.LinearRegression()

# %% [markdown]
# **Regresión Lineal**

# %%
mi_modelo
# Out:
# LinearRegression()

# %%
mi_modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(mi_modelo.coef_)
# Out:
# [[ 1.00000000e+00 -1.33801996e-12 -1.07421652e-12  1.84183631e-12
#   -1.13804348e-12 -1.60800996e-12 -3.67974836e-12  8.75463260e-12
#   -4.18004941e-12  4.52785456e-12 -3.36786262e-12]
#  [ 1.18443273e-15  1.00000000e+00 -2.99760217e-15 -7.77156117e-15
#    8.65973959e-15  1.44328993e-15 -2.99760217e-15 -6.66133815e-16
#    4.99600361e-15 -2.55351296e-15 -9.43689571e-16]
#  [ 3.66879432e-16  7.77156117e-16  1.00000000e+00 -1.81799020e-15
#    1.97064587e-15  4.85722573e-16 -8.04911693e-16 -1.38777878e-15
#    1.91513472e-15 -2.77555756e-16 -8.32667268e-17]
#  [ 3.03515567e-16 -2.27595720e-15  1.62370117e-15  1.00000000e+00
#   -3.16413562e-15 -2.12330153e-15 -4.41313652e-15  1.34892097e-14
#   -6.03683770e-15  2.23432384e-15 -1.31838984e-15]
#  [ 1.56917106e-15 -1.22124533e-15  5.55111512e-16 -3.55271368e-15
#    1.00000000e+00  5.68989300e-16  1.26287869e-15 -2.78943535e-15
#    2.08166817e-15 -1.92901251e-15  2.63677968e-16]
# ...

# %%
y_estimado = mi_modelo.predict(X_test)
y_estimado
# Out:
# array([[ 102356.84148508,   90884.43537161,   90990.59402833,
#           88612.43516819,   85508.47165354,   81465.04541349,
#           78850.67339123,   77635.01678579,   77417.75508223,
#           75204.3463068 ,   73902.47516363],
#        [   3372.80331247,    3070.79424433,    2980.75149669,
#            2979.70263723,    2960.78595412,    2930.6983285 ,
#            2966.40610765,    2953.92718339,    3066.45591639,
#            3016.06107062,    2966.8138665 ],
#        [  87133.19186872,   77015.01122678,   75369.17493795,
#           74708.74971296,   71643.54865989,   67555.15141998,
#           65851.63235309,   64751.15053441,   64724.21124586,
#           62571.16587452,   61379.18975166],
#        [1005096.73029534,  915097.09733375,  888264.20384204,
#          887952.07525332,  882315.42349019,  873347.09251299,
#          883988.98516169,  880270.46672222,  913804.84449364,
#          898786.62667068,  884111.7138672 ],
# ...

# %%
from sklearn.metrics import r2_score

# %%
mi_r2 = r2_score(y_test, y_estimado)
mi_r2
# Out:
# 1.0

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_estimado, color='red', linewidth=1)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test,y_estimado))
# Out:
# MAE 2.3146888204130598e-09

# %% [markdown]
# *Error Medio Absoluto (MAE):*
#
# *Mide el promedio de las diferencias absolutas entre las
# predicciones del modelo y los valores reales.*

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test,y_estimado))
# Out:
# MSE 8.205027026297818e-18

# %% [markdown]
# *Error Cuadrático Medio (MSE):*
#
# *Calcula el promedio de los errores al cuadrado entre las
# predicciones del modelo y los valores reales.*

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_estimado)))
# Out:
# RMSE 2.86444183503485e-09

# %% [markdown]
# *Raíz del Error Cuadrático Medio (RMSE):*
#
# *Es la raíz cuadrada del MSE y proporciona
# una medida en la misma escala que la variable objetivo original.*

# %%
print("RMSE",np.log(np.sqrt(mean_squared_error(y_test,y_estimado))))
# Out:
# RMSE -19.670892327737338

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_estimado)
print(r2)
# Out:
# 1.0

# %% [markdown]
# *Coeficiente de Determinación (R²):*
#
# *Mide la proporción de la varianza de la variable objetivo que es explicada por el modelo.*

# %% [markdown]
# **CrossValidation**

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# *El método K-Fold Cross-Validation es también un proceso iterativo. Consiste en dividir los datos de forma aleatoria en k grupos de aproximadamente el mismo tamaño, k-1 grupos se emplean para entrenar el modelo y uno de los grupos se emplea como validación.*

# %%
X = Emisiones.iloc[:, :-1]
y = Emisiones.iloc[:, -1]

# %%
model = LinearRegression()

# %% [markdown]
# *Creo un modelo de regresión lineal y un objeto KFold con 10 divisiones*

# %%
kfold = KFold(n_splits=10, random_state=42, shuffle=True)

# %% [markdown]
# *Finalmente, aplico la validación cruzada utilizando el método cross_val_score*

# %%
results = cross_val_score(model, X, y, cv=kfold)

# %% [markdown]
# *Resultado*

# %%
print("R-squared: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# R-squared: 99.45% (1.51%)

# %% [markdown]
# *El coeficiente de determinación (R-cuadrado) es una medida estadística que indica qué tan bien se ajusta el modelo a los datos. El R-cuadrado varía entre 0 y 1, donde 0 indica que el modelo no explica la variabilidad de los datos y 1 indica que el modelo explica toda la variabilidad de los datos.
# En este caso, el R-cuadrado es del 99.45%, lo que indica que el modelo se ajusta muy bien a los datos. El valor de 1.51% indica la desviación estándar de los resultados de la validación cruzada, lo que indica la variabilidad en la precisión del modelo.*

# %% [markdown]
# **RandomForestRegressor vs XGBRegressor**

# %% [markdown]
# *Ambos métodos fueron entrenados con los mismos datos. Estos son los contaminantes que están más cerca del porcentaje promedio de reducción. Luego fueron testeados con cinco contaminantes de la matriz.*

# %% [markdown]
# **RandomForestRegressor**

# %%
from sklearn.ensemble import RandomForestRegressor
X_train=Emisiones.iloc[[1,2,3,15],:]
y_train=Emisiones.iloc[[1,2,3,15],:]
X_test=Emisiones.iloc[[16,4,5,9,7],:]

# %%
clf = RandomForestRegressor(n_estimators=8)
clf
# Out:
# RandomForestRegressor(n_estimators=8)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=8)

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([[ 36399.40984981,  32895.6244035 ,  33096.60591655,
#          32868.1039573 ,  32224.44648839,  30868.18203451,
#          30195.32231374,  29493.76316998,  29139.93831689,
#          28955.63897445,  28595.51995852],
#        [ 76864.11800128,  69986.79161021,  70365.06447395,
#          71283.3284186 ,  70408.87531433,  67629.86761899,
#          66535.43487172,  64577.02903859,  62910.10792399,
#          61915.69296238,  60998.54004775],
#        [625625.51179626, 570346.37049585, 573363.55448245,
#         582712.1613049 , 576243.37040375, 553737.74176423,
#         545266.57887797, 528688.1666647 , 513889.66844082,
#         504985.82183285, 497311.09919196],
#        [ 76864.11800128,  69986.79161021,  70365.06447395,
#          71283.3284186 ,  70408.87531433,  67629.86761899,
#          66535.43487172,  64577.02903859,  62910.10792399,
#          61915.69296238,  60998.54004775],
#        [  5254.85834226,   4742.48978179,   4772.08151936,
# ...

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 187217808560.0189

# %% [markdown]
# *Error Cuadrático Medio (MSE):*
#
# *Calcula el promedio de los errores al cuadrado entre las predicciones del modelo y los valores reales.*

# %% [markdown]
# **XGBRegressor**

# %%
import xgboost as xgb
X_train=Emisiones.iloc[[1,2,3,15],:]
y_train=Emisiones.iloc[[1,2,3,15],:]
X_test=Emisiones.iloc[[16,4,5,9,7],:]

# %%
clf = xgb.XGBRegressor(n_estimators=8)
clf
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=8, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
clf.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=8, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([[ 102836.234,   99944.99 ,  100106.89 ,  100250.484,   99813.875,
#          101033.72 ,  100472.37 ,   99604.13 ,   98931.11 ,   98536.88 ,
#           98121.7  ],
#        [ 102836.234,   99944.99 ,  100106.89 ,  100250.484,   99813.875,
#          101033.72 ,  100472.37 ,   99604.13 ,   98931.11 ,   98536.88 ,
#           98121.7  ],
#        [1808450.5  , 1661730.8  , 1669729.9  , 1695284.9  , 1678326.8  ,
#         1618529.6  , 1596168.6  , 1551851.2  , 1512045.5  , 1488069.8  ,
#         1467585.6  ],
#        [ 119332.19 ,  115413.72 ,  115630.48 ,  116049.31 ,  115521.39 ,
#          101033.72 ,  100472.37 ,   99604.13 ,   98931.11 ,   98536.88 ,
#           98121.7  ],
#        [ 102836.234,   99944.99 ,  100106.89 ,  100250.484,   99813.875,
#          101033.72 ,  100472.37 ,   99604.13 ,   98931.11 ,   98536.88 ,
#           98121.7  ]], dtype=float32)

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 607620237155.177

# %% [markdown]
# *Error Cuadrático Medio (MSE):*
#
# *Calcula el promedio de los errores al cuadrado entre las predicciones del modelo y los valores reales.*

# %% [markdown]
# **Conclusión**

# %% [markdown]
# *Habiendo probado ambos modelos de Machine Learning y evaluando el promedio de los errores al cuadrado entre las precciones y los valores reales puedo concluir que ninguno de los dos modelos se adapta en las condiciones realizadas ya que dichos errores son altísimos, queda seguir investigando y probando diferentes alternativas. Ahora bien si tuviera que elegir el que menos error tuvo este fue **RandomForestRegressor**.*
